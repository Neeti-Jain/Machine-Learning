# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeti-Jain/Machine-Learning/blob/master/CustomerSegmentation/CustomerSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !ls ~/.kaggle

# %%
# !ls -l ~/.kaggle

# %%
# !cat ~/.kaggle/kaggle.json

# %%
# !pip install -q kaggle

# %%
# !pip install -q kaggle-cli

# %%
# !kaggle datasets list

# %%
# !kaggle competitions list

# %%
# !kaggle competitions list -s microsoft-malware-prediction

# %%
kaggle competitions download microsoft-malware-prediction

# %%
# !kaggle datasets download -d carrie1/ecommerce-data

# %%
# !unzip -d ecomm ecommerce-data.zip

# %%
import pandas as pd
from datetime import datetime

infile=pd.read_csv('ecomm/data.csv',encoding='ISO-8859-1')
(infile.columns)
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#Converting the format of Date to another format
infile['InvoiceDate']=infile['InvoiceDate'].apply(lambda x:datetime.strptime(x, '%m/%d/%Y %H:%M').strftime('%Y-%m-%d'))
print(infile.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %%
p=infile['InvoiceDate'].min()
print('min',p)
q=infile['InvoiceDate'].max()
print('max',q)
# Out:
# min 2010-12-01
# max 2011-12-09

# %%
infile
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
#infile=infile['CustomerID'].dropna()
infile.dropna(subset=['CustomerID'],inplace=True)
infile
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
#infile['Quantity']=infile.drop([[infile['Quantity']]]== 0)
#df.drop(df.index[2])
infile.drop(infile[infile['Quantity']==0])
#infile.drop(infile['Quantity'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-f796adcd92a4> in <module>()
# ----> 1 infile.drop(infile[infile['Quantity']==0])
#       2 #infile.drop(infile['Quantity'])
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
# ...

# %%
#infile.groupby(['InvoiceDate','CustomerID'])
RFM=pd.DataFrame(columns=['R','F','M'])
RFM.head()
# Out:
# Empty DataFrame
# Columns: [R, F, M]
# Index: []

# %%
#F
RFM['F']=infile.groupby(by=['CustomerID'])['InvoiceNo'].nunique()
RFM.head()
# Out:
#               R  F    M
# CustomerID
# 12346.0     NaN  2  NaN
# 12347.0     NaN  7  NaN
# 12348.0     NaN  4  NaN
# 12349.0     NaN  1  NaN
# 12350.0     NaN  1  NaN

# %%
#R
import datetime as dt
NOW = dt.datetime(2011,12,10)
#infile['InvoiceDate']=infile['InvoiceDate'].apply(lambda x:datetime.strptime(x, '%m/%d/%Y %H:%M').strftime('%Y-%m-%d'))
RFM['R'] = infile.groupby('CustomerID').max()['InvoiceDate'].apply( lambda x: (NOW - datetime.strptime(x,'%Y-%m-%d')).days)
RFM['R'].head()
# Out:
# CustomerID
# 12346.0    326
# 12347.0      3
# 12348.0     76
# 12349.0     19
# 12350.0    311
# Name: R, dtype: int64

# %%
#M
M_df=infile[['CustomerID','UnitPrice','Quantity']]
M_df['Sales']=infile['UnitPrice']*infile['Quantity']
RFM['M']=M_df.groupby(by=['CustomerID']).sum()['Sales']
RFM.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               R  F        M
# CustomerID
# 12346.0     326  2     0.00
# 12347.0       3  7  4310.00
# 12348.0      76  4  1797.24
# 12349.0      19  1  1757.55
# 12350.0     311  1   334.40

# %%
import numpy as np
quantiles = RFM.quantile(q=[0.25,0.5,0.75])
quantiles
# Out:
#           R    F          M
# 0.25   17.0  1.0   293.3625
# 0.50   51.0  3.0   648.0750
# 0.75  144.0  5.0  1611.7250

# %%
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'F': {0.25: 1.0, 0.5: 3.0, 0.75: 5.0},
#  'M': {0.25: 293.36250000000007,
#   0.5: 648.0750000000002,
#   0.75: 1611.7249999999995},
#  'R': {0.25: 17.0, 0.5: 51.0, 0.75: 144.0}}

# %%
segmented_rfm = RFM

# %%
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
segmented_rfm['r_quartile'] = segmented_rfm['R'].apply(RScore, args=('R',quantiles,))
segmented_rfm['f_quartile'] = segmented_rfm['F'].apply(FMScore, args=('F',quantiles,))
segmented_rfm['m_quartile'] = segmented_rfm['M'].apply(FMScore, args=('M',quantiles,))

# %%
segmented_rfm.head()
# Out:
#               R  F        M  r_quartile  f_quartile  m_quartile
# CustomerID
# 12346.0     326  2     0.00           4           3           4
# 12347.0       3  7  4310.00           1           1           1
# 12348.0      76  4  1797.24           3           2           1
# 12349.0      19  1  1757.55           2           4           1
# 12350.0     311  1   334.40           4           4           3

# %%
segmented_rfm['RFMScore'] = segmented_rfm.r_quartile.map(str) \
                            + segmented_rfm.f_quartile.map(str) \
                            + segmented_rfm.m_quartile.map(str)
segmented_rfm.head()
# Out:
#               R  F        M  r_quartile  f_quartile  m_quartile RFMScore
# CustomerID
# 12346.0     326  2     0.00           4           3           4      434
# 12347.0       3  7  4310.00           1           1           1      111
# 12348.0      76  4  1797.24           3           2           1      321
# 12349.0      19  1  1757.55           2           4           1      241
# 12350.0     311  1   334.40           4           4           3      443

# %%
segmented_rfm[segmented_rfm['RFMScore']=='111'].sort_values('M', ascending=False).head(10)
# Out:
#              R    F          M  r_quartile  f_quartile  m_quartile RFMScore
# CustomerID
# 14646.0      2   77  279489.02           1           1           1      111
# 18102.0      1   62  256438.49           1           1           1      111
# 17450.0      9   55  187482.17           1           1           1      111
# 14911.0      2  248  132572.62           1           1           1      111
# 14156.0     10   66  113384.14           1           1           1      111
# 17511.0      3   46   88125.38           1           1           1      111
# 16684.0      5   31   65892.08           1           1           1      111
# 13694.0      4   60   62653.10           1           1           1      111
# 15311.0      1  118   59419.34           1           1           1      111
# 13089.0      3  118   57385.88           1           1           1      111
